# %% [markdown]
# # **Index & Slice**

# %% [markdown]
# ![Screenshot 2023-11-03 194412.png](<attachment:Screenshot 2023-11-03 194412.png>)

# %% [markdown]
# ![giphy.gif](attachment:giphy.gif)

# %%
st='ABCDEFGHIJKLMNOPQRSTUVWXYZ'

# %%
len(st)
# Out:
# 26

# %%
st[0]
# Out:
# 'A'

# %%
st[25]
# Out:
# 'Z'

# %%
st[3]
# Out:
# 'D'

# %%
st[26]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\Python\3_Index_&_Slice.ipynb Cell 9 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Python/3_Index_%26_Slice.ipynb#X60sZmlsZQ%3D%3D?line=0'>1</a> st[26]
#
# IndexError: string index out of range

# %%
st
# Out:
# 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'

# %%
st[0:4]
# Out:
# 'ABCD'

# %%
st[2:6]
# Out:
# 'CDEF'

# %%
st[5]
# Out:
# 'F'

# %%
st[5:]
# Out:
# 'FGHIJKLMNOPQRSTUVWXYZ'

# %%
st[:7]
# Out:
# 'ABCDEFG'

# %%
st[0:7]
# Out:
# 'ABCDEFG'

# %%
st1="Python"

# %%
st1[2:4]
# Out:
# 'th'

# %%
st1[-6]
# Out:
# 'P'

# %%
st1[-5]
# Out:
# 'y'

# %%
st1[-4:-2]
# Out:
# 'th'

# %%
st1[-1]
# Out:
# 'n'

# %%
"Hello Python"[6]
# Out:
# 'P'

# %%
"Hello Python"[6:]
# Out:
# 'Python'
